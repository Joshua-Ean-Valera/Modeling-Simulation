# %% [markdown]
# # Discrete Event Simulation (DES) of an Automated Teller Machine (ATM)
#
# ## Introduction
# This activity introduces the concept of Discrete Event Simulation (DES) by modeling the operations of an Automated Teller Machine (ATM) system. You will learn how to simulate customer arrivals, ATM service, and various scenarios that can occur during a transaction, such as insufficient cash in the ATM, customer insufficient funds, and specific withdrawal denominations.

# %% [markdown]
# ## Learning Objectives
# Upon completion of this activity, you should be able to:
# - Understand the basic principles of Discrete Event Simulation.
# - Model a real-world system (ATM) using DES concepts.
# - Implement event-driven simulation logic.
# - Handle various scenarios and conditions within a simulation.
# - Analyze and interpret simulation results.

# %% [markdown]
# ## Problem Description: ATM Simulation
#
# Simulate a bank with 3 ATM machines. The simulation should model customer interactions with the ATMs, considering the following scenarios:
#
# ### ATM Constraints and Scenarios:
# 1.  **Cash Dispensing Issues**: An ATM may not be able to dispense money due to:
#     *   **No Available Cash**: The ATM has run out of cash.
#     *   **Large Withdrawal Amount**: The customer attempts to withdraw an amount larger than the ATM's current cash reserves, or an amount that cannot be dispensed with available denominations.
#     *   If an ATM cannot dispense the requested amount, the customer should attempt to use another available machine or re-enter the amount.
# 2.  **Customer Insufficient Funds**: A customer may have insufficient funds in their account to complete a withdrawal. In this case, the transaction should be declined.
# 3.  **Paper Money Denominations**: Customers can only withdraw money in denominations of 100, 500, and 1000.
#
# ### Simulation Requirements:
# -   Model customer arrivals as a random process.
# -   Model ATM service time.
# -   Keep track of the state of each ATM (available, busy, out of cash).
# -   Record key metrics such as:
#     *   Average customer waiting time.
#     *   Number of customers served.
#     *   Number of rejected transactions (due to ATM cash, customer funds, or denomination issues).
#     *   ATM utilization.

# %% [markdown]
# ## Task: Data Visualization
#
# To enhance the analysis of the ATM simulation, create meaningful plots and graphs based on the collected simulation metrics. The more visualizations, the better. Consider the following:
#
# -   **Create Simulation Assumptions**: Formulate 5 clear and concise assumptions that underpin your simulation model. These assumptions should address aspects not explicitly defined in the problem description but are necessary for the simulation to run.
# -   **Customer Waiting Time Distribution**: A histogram or density plot to show the distribution of customer waiting times.
# -   **ATM Utilization**: A bar chart or pie chart showing the utilization of each ATM.
# -   **Transaction Outcomes**: A bar chart or pie chart illustrating the proportion of successful transactions versus rejected transactions (categorized by reason: insufficient funds, ATM cash issues, no available ATM).
# -   **Cash Remaining in ATMs**: A plot showing the cash level in each ATM over time (if time-series data is collected).
# -   **Customers Served Over Time**: A line graph showing the cumulative number of customers served over the simulation duration.
#
# Implement the code to generate these plots using appropriate Python libraries (e.g., `matplotlib`, `seaborn`, `plotly`).
#
# SEE THE EXAMPLE PLOTS BELOW

# %%
import simpy
import random
import collections

# --- Configuration Parameters ---
RANDOM_SEED = random.randint(1, 10000)
NUM_ATMS = 3  # Number of ATM machines
ATM_CAPACITY = 200000  # Each ATM starts with 200,000 units of cash
DISPENSE_SERVICE_TIME = 0.10  # Time to dispense money (per Bank Note)
MIN_WITHDRAWAL = 1000
MAX_WITHDRAWAL = 10000
CUSTOMER_ARRIVAL_INTERVAL = 10  # Average time between customer arrivals (minutes)
SIM_DURATION = 500  # Simulation duration (minutes)

DENOMINATIONS = [1000, 500, 100]
CUSTOMER_FUNDS_RANGE = (1000, 100000) # Customers have between 1,000 and 100,000 in their account

# Set up random seed for reproducibility
random.seed(RANDOM_SEED)

# %%
class ATM:
    def __init__(self, env, name, capacity):
        self.env = env
        self.name = name
        self.cash = simpy.Container(env, init=capacity, capacity=capacity)

    def dispense_cash(self, amount):
        yield self.env.timeout(amount * DISPENSE_SERVICE_TIME / 100) # Simulate time to dispense
        self.cash.get(amount)

    def check_and_dispense(self, amount):
        if self.cash.level < amount:
            return False, "ATM has insufficient cash."

        # Check if amount can be dispensed with available denominations
        temp_amount = amount
        for denom in DENOMINATIONS:
            while temp_amount >= denom and self.cash.level >= denom:
                temp_amount -= denom
        if temp_amount != 0:
            return False, "Cannot dispense exact amount with available denominations."

        return True, "Cash can be dispensed."

# %%
def customer(env, name, atm_store, metrics):
    arrival_time = env.now
    print(f"{env.now:.2f}: Customer {name} arrived.")
    metrics['customers_arrived'] += 1

    withdrawal_amount = random.choice(DENOMINATIONS) * random.randint(1, 50) # Withdraw in multiples of 100, 500, 1000
    customer_funds = random.randint(*CUSTOMER_FUNDS_RANGE)

    print(f"{env.now:.2f}: Customer {name} wants to withdraw {withdrawal_amount} (has {customer_funds}).")

    if customer_funds < withdrawal_amount:
        print(f"{env.now:.2f}: Customer {name} has insufficient funds. Transaction rejected.")
        metrics['rejected_insufficient_funds'] += 1
        metrics['customer_waiting_times'].append(env.now - arrival_time)
        return

    # Customer tries to withdraw, potentially trying multiple ATMs
    transaction_successful = False
    attempts = 0
    while not transaction_successful and attempts < NUM_ATMS:
        attempts += 1
        print(f"{env.now:.2f}: Customer {name} waiting for an ATM (attempt {attempts}/{NUM_ATMS}).")
        
        # Request an ATM from the store
        with atm_store.get() as get_atm_request:
            atm = yield get_atm_request # Get an ATM from the store

            print(f"{env.now:.2f}: Customer {name} got ATM {atm.name}.")
            
            # Check ATM cash and denomination
            can_dispense, reason = atm.check_and_dispense(withdrawal_amount)
            if can_dispense:
                print(f"{env.now:.2f}: Customer {name} using ATM {atm.name} to withdraw {withdrawal_amount}.")
                yield env.process(atm.dispense_cash(withdrawal_amount))
                print(f"{env.now:.2f}: Customer {name} successfully withdrew {withdrawal_amount} from ATM {atm.name}. Remaining cash: {atm.cash.level}")
                metrics['customers_served'] += 1
                metrics['customer_waiting_times'].append(env.now - arrival_time)
                transaction_successful = True
            else:
                print(f"{env.now:.2f}: ATM {atm.name} cannot dispense for Customer {name}: {reason}")
                metrics['rejected_atm_issues'] += 1
                # Customer will try another ATM, so put this one back
                print(f"{env.now:.2f}: Customer {name} returning ATM {atm.name} and will try another.")
            
            yield atm_store.put(atm) # Return the ATM to the store

        if not transaction_successful and attempts < NUM_ATMS:
            # If transaction was not successful, wait a short time before trying another ATM
            yield env.timeout(1) # Simulate a small delay before trying again
    
    if not transaction_successful:
        print(f"{env.now:.2f}: Customer {name} could not withdraw from any ATM after {NUM_ATMS} attempts and left.")
        metrics['rejected_no_available_atm'] += 1
        metrics['customer_waiting_times'].append(env.now - arrival_time)
    else:
        print(f"{env.now:.2f}: Customer {name} completed transaction.")

# %%
def customer_generator(env, atm_store, metrics, arrival_interval):
    i = 0
    while True:
        yield env.timeout(random.expovariate(1.0 / arrival_interval))
        i += 1
        env.process(customer(env, f'{i}', atm_store, metrics))

def setup_environment(env, num_atms, atm_capacity):
    atms = [ATM(env, f'ATM {i+1}', atm_capacity) for i in range(num_atms)]
    atm_store = simpy.Store(env)
    for atm in atms:
        atm_store.put(atm)
    metrics = collections.defaultdict(int)
    metrics['customer_waiting_times'] = []
    return atms, atm_store, metrics


print("--- ATM Simulation ---")
env = simpy.Environment()
atms, atm_store, metrics = setup_environment(env, NUM_ATMS, ATM_CAPACITY)
env.process(customer_generator(env, atm_store, metrics, CUSTOMER_ARRIVAL_INTERVAL))
env.run(until=SIM_DURATION)

print("\n--- Simulation Metrics ---")
print(f"Customers Arrived: {metrics['customers_arrived']}")
print(f"Customers Served: {metrics['customers_served']}")
print(f"Rejected (Insufficient Funds): {metrics['rejected_insufficient_funds']}")
print(f"Rejected (ATM Issues): {metrics['rejected_atm_issues']}")
print(f"Rejected (No Available ATM): {metrics['rejected_no_available_atm']}")

if metrics['customer_waiting_times']:
    avg_wait_time = sum(metrics['customer_waiting_times']) / len(metrics['customer_waiting_times'])
    print(f"Average Customer Waiting Time: {avg_wait_time:.2f} minutes")
else:
    print("No customer waiting times to calculate.")

# Calculate ATM Utilization (simplified - could be more detailed)
for atm in atms:
    # This is a simplified view. A more accurate utilization would track busy time.
    # For now, we can infer based on cash dispensed.
    cash_dispensed = ATM_CAPACITY - atm.cash.level
    print(f"ATM {atm.name} Cash Remaining: {atm.cash.level} (Dispensed: {cash_dispensed})")
# Out:
# --- ATM Simulation ---
# 16.53: Customer 1 arrived.
# 16.53: Customer 1 wants to withdraw 1700 (has 13451).
# 16.53: Customer 1 waiting for an ATM (attempt 1/3).
# 16.53: Customer 1 got ATM ATM 1.
# 16.53: Customer 1 using ATM ATM 1 to withdraw 1700.
# 17.23: Customer 2 arrived.
# 17.23: Customer 2 wants to withdraw 600 (has 78701).
# 17.23: Customer 2 waiting for an ATM (attempt 1/3).
# 17.23: Customer 2 got ATM ATM 2.
# 17.23: Customer 2 using ATM ATM 2 to withdraw 600.
# 17.83: Customer 2 successfully withdrew 600 from ATM ATM 2. Remaining cash: 199400
# 17.83: Customer 2 completed transaction.
# 18.23: Customer 1 successfully withdrew 1700 from ATM ATM 1. Remaining cash: 198300
# 18.23: Customer 1 completed transaction.
# 19.85: Customer 3 arrived.
# 19.85: Customer 3 wants to withdraw 2500 (has 95697).
# 19.85: Customer 3 waiting for an ATM (attempt 1/3).
# 19.85: Customer 3 got ATM ATM 3.
# 19.85: Customer 3 using ATM ATM 3 to withdraw 2500.
# 22.35: Customer 3 successfully withdrew 2500 from ATM ATM 3. Remaining cash: 197500
# 22.35: Customer 3 completed transaction.
# 26.50: Customer 4 arrived.
# 26.50: Customer 4 wants to withdraw 23000 (has 14206).
# 26.50: Customer 4 has insufficient funds. Transaction rejected.
# 41.18: Customer 5 arrived.
# 41.18: Customer 5 wants to withdraw 2200 (has 86937).
# 41.18: Customer 5 waiting for an ATM (attempt 1/3).
# 41.18: Customer 5 got ATM ATM 2.
# 41.18: Customer 5 using ATM ATM 2 to withdraw 2200.
# 43.38: Customer 5 successfully withdrew 2200 from ATM ATM 2. Remaining cash: 197200
# 43.38: Customer 5 completed transaction.
# 46.41: Customer 6 arrived.
# 46.41: Customer 6 wants to withdraw 8500 (has 99991).
# 46.41: Customer 6 waiting for an ATM (attempt 1/3).
# 46.41: Customer 6 got ATM ATM 1.
# 46.41: Customer 6 using ATM ATM 1 to withdraw 8500.
# 51.50: Customer 7 arrived.
# 51.50: Customer 7 wants to withdraw 8000 (has 37095).
# 51.50: Customer 7 waiting for an ATM (attempt 1/3).
# 51.50: Customer 7 got ATM ATM 3.
# 51.50: Customer 7 using ATM ATM 3 to withdraw 8000.
# 54.91: Customer 6 successfully withdrew 8500 from ATM ATM 1. Remaining cash: 189800
# 54.91: Customer 6 completed transaction.
# 59.50: Customer 7 successfully withdrew 8000 from ATM ATM 3. Remaining cash: 189500
# 59.50: Customer 7 completed transaction.
# 66.44: Customer 8 arrived.
# 66.44: Customer 8 wants to withdraw 4700 (has 74123).
# 66.44: Customer 8 waiting for an ATM (attempt 1/3).
# 66.44: Customer 8 got ATM ATM 2.
# 66.44: Customer 8 using ATM ATM 2 to withdraw 4700.
# 71.14: Customer 8 successfully withdrew 4700 from ATM ATM 2. Remaining cash: 192500
# 71.14: Customer 8 completed transaction.
# 73.70: Customer 9 arrived.
# 73.70: Customer 9 wants to withdraw 4500 (has 21364).
# 73.70: Customer 9 waiting for an ATM (attempt 1/3).
# 73.70: Customer 9 got ATM ATM 1.
# 73.70: Customer 9 using ATM ATM 1 to withdraw 4500.
# 78.20: Customer 9 successfully withdrew 4500 from ATM ATM 1. Remaining cash: 185300
# 78.20: Customer 9 completed transaction.
# 82.02: Customer 10 arrived.
# 82.02: Customer 10 wants to withdraw 23000 (has 87036).
# 82.02: Customer 10 waiting for an ATM (attempt 1/3).
# 82.02: Customer 10 got ATM ATM 3.
# 82.02: Customer 10 using ATM ATM 3 to withdraw 23000.
# 89.71: Customer 11 arrived.
# 89.71: Customer 11 wants to withdraw 20500 (has 42120).
# 89.71: Customer 11 waiting for an ATM (attempt 1/3).
# 89.71: Customer 11 got ATM ATM 2.
# 89.71: Customer 11 using ATM ATM 2 to withdraw 20500.
# 105.02: Customer 10 successfully withdrew 23000 from ATM ATM 3. Remaining cash: 166500
# 105.02: Customer 10 completed transaction.
# 106.26: Customer 12 arrived.
# 106.26: Customer 12 wants to withdraw 14500 (has 71680).
# 106.26: Customer 12 waiting for an ATM (attempt 1/3).
# 106.26: Customer 12 got ATM ATM 1.
# 106.26: Customer 12 using ATM ATM 1 to withdraw 14500.
# 109.24: Customer 13 arrived.
# 109.24: Customer 13 wants to withdraw 5000 (has 10636).
# 109.24: Customer 13 waiting for an ATM (attempt 1/3).
# 109.24: Customer 13 got ATM ATM 3.
# 109.24: Customer 13 using ATM ATM 3 to withdraw 5000.
# 110.21: Customer 11 successfully withdrew 20500 from ATM ATM 2. Remaining cash: 172000
# 110.21: Customer 11 completed transaction.
# 112.13: Customer 14 arrived.
# 112.13: Customer 14 wants to withdraw 1400 (has 28973).
# 112.13: Customer 14 waiting for an ATM (attempt 1/3).
# 112.13: Customer 14 got ATM ATM 2.
# 112.13: Customer 14 using ATM ATM 2 to withdraw 1400.
# 113.53: Customer 14 successfully withdrew 1400 from ATM ATM 2. Remaining cash: 170600
# 113.53: Customer 14 completed transaction.
# 114.24: Customer 13 successfully withdrew 5000 from ATM ATM 3. Remaining cash: 161500
# 114.24: Customer 13 completed transaction.
# 120.76: Customer 12 successfully withdrew 14500 from ATM ATM 1. Remaining cash: 170800
# 120.76: Customer 12 completed transaction.
# 144.50: Customer 15 arrived.
# 144.50: Customer 15 wants to withdraw 1500 (has 70746).
# 144.50: Customer 15 waiting for an ATM (attempt 1/3).
# 144.50: Customer 15 got ATM ATM 2.
# 144.50: Customer 15 using ATM ATM 2 to withdraw 1500.
# 146.00: Customer 15 successfully withdrew 1500 from ATM ATM 2. Remaining cash: 169100
# 146.00: Customer 15 completed transaction.
# 154.10: Customer 16 arrived.
# 154.10: Customer 16 wants to withdraw 3900 (has 63410).
# 154.10: Customer 16 waiting for an ATM (attempt 1/3).
# 154.10: Customer 16 got ATM ATM 3.
# 154.10: Customer 16 using ATM ATM 3 to withdraw 3900.
# 155.56: Customer 17 arrived.
# 155.56: Customer 17 wants to withdraw 18500 (has 5100).
# 155.56: Customer 17 has insufficient funds. Transaction rejected.
# 158.00: Customer 16 successfully withdrew 3900 from ATM ATM 3. Remaining cash: 157600
# 158.00: Customer 16 completed transaction.
# 167.26: Customer 18 arrived.
# 167.26: Customer 18 wants to withdraw 8000 (has 46933).
# 167.26: Customer 18 waiting for an ATM (attempt 1/3).
# 167.26: Customer 18 got ATM ATM 1.
# 167.26: Customer 18 using ATM ATM 1 to withdraw 8000.
# 175.09: Customer 19 arrived.
# 175.09: Customer 19 wants to withdraw 34000 (has 49836).
# 175.09: Customer 19 waiting for an ATM (attempt 1/3).
# 175.09: Customer 19 got ATM ATM 2.
# 175.09: Customer 19 using ATM ATM 2 to withdraw 34000.
# 175.26: Customer 18 successfully withdrew 8000 from ATM ATM 1. Remaining cash: 162800
# 175.26: Customer 18 completed transaction.
# 187.79: Customer 20 arrived.
# 187.79: Customer 20 wants to withdraw 4000 (has 22245).
# 187.79: Customer 20 waiting for an ATM (attempt 1/3).
# 187.79: Customer 20 got ATM ATM 3.
# 187.79: Customer 20 using ATM ATM 3 to withdraw 4000.
# 191.79: Customer 20 successfully withdrew 4000 from ATM ATM 3. Remaining cash: 153600
# 191.79: Customer 20 completed transaction.
# 197.22: Customer 21 arrived.
# 197.22: Customer 21 wants to withdraw 25000 (has 27898).
# 197.22: Customer 21 waiting for an ATM (attempt 1/3).
# 197.22: Customer 21 got ATM ATM 1.
# 197.22: Customer 21 using ATM ATM 1 to withdraw 25000.
# 199.69: Customer 22 arrived.
# 199.69: Customer 22 wants to withdraw 4500 (has 16854).
# 199.69: Customer 22 waiting for an ATM (attempt 1/3).
# 199.69: Customer 22 got ATM ATM 3.
# 199.69: Customer 22 using ATM ATM 3 to withdraw 4500.
# 204.19: Customer 22 successfully withdrew 4500 from ATM ATM 3. Remaining cash: 149100
# 204.19: Customer 22 completed transaction.
# 209.09: Customer 19 successfully withdrew 34000 from ATM ATM 2. Remaining cash: 135100
# 209.09: Customer 19 completed transaction.
# 222.22: Customer 21 successfully withdrew 25000 from ATM ATM 1. Remaining cash: 137800
# 222.22: Customer 21 completed transaction.
# 228.54: Customer 23 arrived.
# 228.54: Customer 23 wants to withdraw 22000 (has 93929).
# 228.54: Customer 23 waiting for an ATM (attempt 1/3).
# 228.54: Customer 23 got ATM ATM 3.
# 228.54: Customer 23 using ATM ATM 3 to withdraw 22000.
# 244.68: Customer 24 arrived.
# 244.68: Customer 24 wants to withdraw 2700 (has 47782).
# 244.68: Customer 24 waiting for an ATM (attempt 1/3).
# 244.68: Customer 24 got ATM ATM 2.
# 244.68: Customer 24 using ATM ATM 2 to withdraw 2700.
# 247.38: Customer 24 successfully withdrew 2700 from ATM ATM 2. Remaining cash: 132400
# 247.38: Customer 24 completed transaction.
# 250.54: Customer 23 successfully withdrew 22000 from ATM ATM 3. Remaining cash: 127100
# 250.54: Customer 23 completed transaction.
# 256.12: Customer 25 arrived.
# 256.12: Customer 25 wants to withdraw 50000 (has 58729).
# 256.12: Customer 25 waiting for an ATM (attempt 1/3).
# 256.12: Customer 25 got ATM ATM 1.
# 256.12: Customer 25 using ATM ATM 1 to withdraw 50000.
# 256.31: Customer 26 arrived.
# 256.31: Customer 26 wants to withdraw 6500 (has 52820).
# 256.31: Customer 26 waiting for an ATM (attempt 1/3).
# 256.31: Customer 26 got ATM ATM 2.
# 256.31: Customer 26 using ATM ATM 2 to withdraw 6500.
# 262.81: Customer 26 successfully withdrew 6500 from ATM ATM 2. Remaining cash: 125900
# 262.81: Customer 26 completed transaction.
# 274.17: Customer 27 arrived.
# 274.17: Customer 27 wants to withdraw 41000 (has 2107).
# 274.17: Customer 27 has insufficient funds. Transaction rejected.
# 287.09: Customer 28 arrived.
# 287.09: Customer 28 wants to withdraw 22000 (has 26916).
# 287.09: Customer 28 waiting for an ATM (attempt 1/3).
# 287.09: Customer 28 got ATM ATM 3.
# 287.09: Customer 28 using ATM ATM 3 to withdraw 22000.
# 294.50: Customer 29 arrived.
# 294.50: Customer 29 wants to withdraw 26000 (has 84944).
# 294.50: Customer 29 waiting for an ATM (attempt 1/3).
# 294.50: Customer 29 got ATM ATM 2.
# 294.50: Customer 29 using ATM ATM 2 to withdraw 26000.
# 306.12: Customer 25 successfully withdrew 50000 from ATM ATM 1. Remaining cash: 87800
# 306.12: Customer 25 completed transaction.
# 308.62: Customer 30 arrived.
# 308.62: Customer 30 wants to withdraw 46000 (has 19430).
# 308.62: Customer 30 has insufficient funds. Transaction rejected.
# 309.09: Customer 28 successfully withdrew 22000 from ATM ATM 3. Remaining cash: 105100
# 309.09: Customer 28 completed transaction.
# 313.73: Customer 31 arrived.
# 313.73: Customer 31 wants to withdraw 5000 (has 78663).
# 313.73: Customer 31 waiting for an ATM (attempt 1/3).
# 313.73: Customer 31 got ATM ATM 1.
# 313.73: Customer 31 using ATM ATM 1 to withdraw 5000.
# 318.73: Customer 31 successfully withdrew 5000 from ATM ATM 1. Remaining cash: 82800
# 318.73: Customer 31 completed transaction.
# 320.50: Customer 29 successfully withdrew 26000 from ATM ATM 2. Remaining cash: 99900
# 320.50: Customer 29 completed transaction.
# 348.20: Customer 32 arrived.
# 348.20: Customer 32 wants to withdraw 5000 (has 35934).
# 348.20: Customer 32 waiting for an ATM (attempt 1/3).
# 348.20: Customer 32 got ATM ATM 3.
# 348.20: Customer 32 using ATM ATM 3 to withdraw 5000.
# 349.59: Customer 33 arrived.
# 349.59: Customer 33 wants to withdraw 5000 (has 25663).
# 349.59: Customer 33 waiting for an ATM (attempt 1/3).
# 349.59: Customer 33 got ATM ATM 1.
# 349.59: Customer 33 using ATM ATM 1 to withdraw 5000.
# 349.83: Customer 34 arrived.
# 349.83: Customer 34 wants to withdraw 2800 (has 98964).
# 349.83: Customer 34 waiting for an ATM (attempt 1/3).
# 349.83: Customer 34 got ATM ATM 2.
# 349.83: Customer 34 using ATM ATM 2 to withdraw 2800.
# 349.95: Customer 35 arrived.
# 349.95: Customer 35 wants to withdraw 1400 (has 28510).
# 349.95: Customer 35 waiting for an ATM (attempt 1/3).
# 352.63: Customer 34 successfully withdrew 2800 from ATM ATM 2. Remaining cash: 97100
# 352.63: Customer 34 completed transaction.
# 352.63: Customer 35 got ATM ATM 2.
# 352.63: Customer 35 using ATM ATM 2 to withdraw 1400.
# 353.20: Customer 32 successfully withdrew 5000 from ATM ATM 3. Remaining cash: 100100
# 353.20: Customer 32 completed transaction.
# 354.03: Customer 35 successfully withdrew 1400 from ATM ATM 2. Remaining cash: 95700
# 354.03: Customer 35 completed transaction.
# 354.59: Customer 33 successfully withdrew 5000 from ATM ATM 1. Remaining cash: 77800
# 354.59: Customer 33 completed transaction.
# 374.14: Customer 36 arrived.
# 374.14: Customer 36 wants to withdraw 20000 (has 96489).
# 374.14: Customer 36 waiting for an ATM (attempt 1/3).
# 374.14: Customer 36 got ATM ATM 3.
# 374.14: Customer 36 using ATM ATM 3 to withdraw 20000.
# 385.64: Customer 37 arrived.
# 385.64: Customer 37 wants to withdraw 27000 (has 2188).
# 385.64: Customer 37 has insufficient funds. Transaction rejected.
# 394.14: Customer 36 successfully withdrew 20000 from ATM ATM 3. Remaining cash: 80100
# 394.14: Customer 36 completed transaction.
# 395.55: Customer 38 arrived.
# 395.55: Customer 38 wants to withdraw 500 (has 74454).
# 395.55: Customer 38 waiting for an ATM (attempt 1/3).
# 395.55: Customer 38 got ATM ATM 2.
# 395.55: Customer 38 using ATM ATM 2 to withdraw 500.
# 396.05: Customer 38 successfully withdrew 500 from ATM ATM 2. Remaining cash: 95200
# 396.05: Customer 38 completed transaction.
# 399.33: Customer 39 arrived.
# 399.33: Customer 39 wants to withdraw 2000 (has 73461).
# 399.33: Customer 39 waiting for an ATM (attempt 1/3).
# 399.33: Customer 39 got ATM ATM 1.
# 399.33: Customer 39 using ATM ATM 1 to withdraw 2000.
# 401.33: Customer 39 successfully withdrew 2000 from ATM ATM 1. Remaining cash: 75800
# 401.33: Customer 39 completed transaction.
# 403.04: Customer 40 arrived.
# 403.04: Customer 40 wants to withdraw 24000 (has 26690).
# 403.04: Customer 40 waiting for an ATM (attempt 1/3).
# 403.04: Customer 40 got ATM ATM 3.
# 403.04: Customer 40 using ATM ATM 3 to withdraw 24000.
# 427.04: Customer 40 successfully withdrew 24000 from ATM ATM 3. Remaining cash: 56100
# 427.04: Customer 40 completed transaction.
# 441.50: Customer 41 arrived.
# 441.50: Customer 41 wants to withdraw 16500 (has 82656).
# 441.50: Customer 41 waiting for an ATM (attempt 1/3).
# 441.50: Customer 41 got ATM ATM 2.
# 441.50: Customer 41 using ATM ATM 2 to withdraw 16500.
# 445.19: Customer 42 arrived.
# 445.19: Customer 42 wants to withdraw 4700 (has 36955).
# 445.19: Customer 42 waiting for an ATM (attempt 1/3).
# 445.19: Customer 42 got ATM ATM 1.
# 445.19: Customer 42 using ATM ATM 1 to withdraw 4700.
# 449.89: Customer 42 successfully withdrew 4700 from ATM ATM 1. Remaining cash: 71100
# 449.89: Customer 42 completed transaction.
# 458.00: Customer 41 successfully withdrew 16500 from ATM ATM 2. Remaining cash: 78700
# 458.00: Customer 41 completed transaction.
# 467.13: Customer 43 arrived.
# 467.13: Customer 43 wants to withdraw 1000 (has 68271).
# 467.13: Customer 43 waiting for an ATM (attempt 1/3).
# 467.13: Customer 43 got ATM ATM 3.
# 467.13: Customer 43 using ATM ATM 3 to withdraw 1000.
# 467.91: Customer 44 arrived.
# 467.91: Customer 44 wants to withdraw 100 (has 24030).
# 467.91: Customer 44 waiting for an ATM (attempt 1/3).
# 467.91: Customer 44 got ATM ATM 1.
# 467.91: Customer 44 using ATM ATM 1 to withdraw 100.
# 468.01: Customer 44 successfully withdrew 100 from ATM ATM 1. Remaining cash: 71000
# 468.01: Customer 44 completed transaction.
# 468.13: Customer 43 successfully withdrew 1000 from ATM ATM 3. Remaining cash: 55100
# 468.13: Customer 43 completed transaction.
# 489.79: Customer 45 arrived.
# 489.79: Customer 45 wants to withdraw 300 (has 62801).
# 489.79: Customer 45 waiting for an ATM (attempt 1/3).
# 489.79: Customer 45 got ATM ATM 2.
# 489.79: Customer 45 using ATM ATM 2 to withdraw 300.
# 490.09: Customer 45 successfully withdrew 300 from ATM ATM 2. Remaining cash: 78400
# 490.09: Customer 45 completed transaction.
# 496.19: Customer 46 arrived.
# 496.19: Customer 46 wants to withdraw 2800 (has 44637).
# 496.19: Customer 46 waiting for an ATM (attempt 1/3).
# 496.19: Customer 46 got ATM ATM 1.
# 496.19: Customer 46 using ATM ATM 1 to withdraw 2800.
# 498.99: Customer 46 successfully withdrew 2800 from ATM ATM 1. Remaining cash: 68200
# 498.99: Customer 46 completed transaction.
#
# --- Simulation Metrics ---
# Customers Arrived: 46
# Customers Served: 41
# Rejected (Insufficient Funds): 5
# Rejected (ATM Issues): 0
# Rejected (No Available ATM): 0
# Average Customer Waiting Time: 8.72 minutes
# ATM ATM 1 Cash Remaining: 68200 (Dispensed: 131800)
# ATM ATM 2 Cash Remaining: 78400 (Dispensed: 121600)
# ATM ATM 3 Cash Remaining: 55100 (Dispensed: 144900)

# %% [markdown]
# ## Simulation Assumptions
#
# Based on the problem description, here are 5 key assumptions for our ATM simulation:
#
# 1. **Customer Arrival Pattern**: Customer arrivals follow an exponential distribution with an average interval of 10 minutes, representing a realistic random arrival pattern for ATM usage.
#
# 2. **Service Time Model**: ATM service time is proportional to the number of bills dispensed (0.10 minutes per 100-unit denomination), representing the physical time needed to count and dispense cash.
#
# 3. **Customer Behavior**: When an ATM cannot fulfill a withdrawal request, customers will attempt to use other available ATMs up to the maximum number of machines (3 attempts) before leaving.
#
# 4. **Initial Cash Distribution**: All ATMs start with the same amount of cash (200,000 units) and operate independently without cash replenishment during the simulation period.
#
# 5. **Withdrawal Constraints**: Customers can only withdraw amounts that are multiples of available denominations (100, 500, 1000), and the system checks both customer account balance and ATM cash availability before processing transactions.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Set up the plotting style
plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 8)

# %%
# 1. Customer Waiting Time Distribution
plt.figure(figsize=(10, 6))
if metrics['customer_waiting_times']:
    plt.hist(metrics['customer_waiting_times'], bins=20, alpha=0.7, color='skyblue', edgecolor='black')
    plt.axvline(np.mean(metrics['customer_waiting_times']), color='red', linestyle='--', 
                label=f'Mean: {np.mean(metrics["customer_waiting_times"]):.2f} min')
    plt.xlabel('Waiting Time (minutes)')
    plt.ylabel('Number of Customers')
    plt.title('Customer Waiting Time Distribution')
    plt.legend()
    plt.grid(True, alpha=0.3)
else:
    plt.text(0.5, 0.5, 'No Data Available', ha='center', va='center')
    plt.title('Customer Waiting Time Distribution')
plt.tight_layout()
plt.show()

# %%
# 2. ATM Utilization
plt.figure(figsize=(10, 6))
atm_names = [f'ATM {i+1}' for i in range(len(atms))]
cash_dispensed = [ATM_CAPACITY - atm.cash.level for atm in atms]
utilization_pct = [(dispensed / ATM_CAPACITY) * 100 for dispensed in cash_dispensed]

plt.bar(atm_names, utilization_pct, color=['lightblue', 'lightgreen', 'lightyellow'][:len(atms)])
plt.xlabel('ATM')
plt.ylabel('Cash Utilization (%)')
plt.title('ATM Utilization (% of Initial Cash Dispensed)')
plt.grid(True, alpha=0.3)
for i, (pct, dispensed) in enumerate(zip(utilization_pct, cash_dispensed)):
    plt.text(i, pct + 1, f'{pct:.1f}%\n(${dispensed:,})', ha='center', va='bottom')
plt.tight_layout()
plt.show()

# %%
# 3. Transaction Outcomes
plt.figure(figsize=(8, 8))
outcomes = {
    'Successful': metrics['customers_served'],
    'Insufficient Funds': metrics['rejected_insufficient_funds'],
    'ATM Issues': metrics['rejected_atm_issues'],
    'No Available ATM': metrics['rejected_no_available_atm']
}
# Filter out zero values
outcomes = {k: v for k, v in outcomes.items() if v > 0}

if outcomes:
    colors = ['lightgreen', 'lightcoral', 'lightyellow', 'lightgray'][:len(outcomes)]
    plt.pie(outcomes.values(), labels=outcomes.keys(), autopct='%1.1f%%', 
            colors=colors, startangle=90)
    plt.title(f'Transaction Outcomes Distribution\n(Total Customers: {metrics["customers_arrived"]})')
else:
    plt.text(0.5, 0.5, 'No Data Available', ha='center', va='center')
    plt.title('Transaction Outcomes Distribution')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# 4. Cash Remaining in ATMs
plt.figure(figsize=(12, 6))
atm_names = [f'ATM {i+1}' for i in range(len(atms))]
cash_remaining = [atm.cash.level for atm in atms]
cash_dispensed = [ATM_CAPACITY - remaining for remaining in cash_remaining]

x = np.arange(len(atm_names))
width = 0.35

plt.bar(x - width/2, cash_remaining, width, label='Cash Remaining', color='lightblue', alpha=0.7)
plt.bar(x + width/2, cash_dispensed, width, label='Cash Dispensed', color='lightcoral', alpha=0.7)

plt.xlabel('ATM')
plt.ylabel('Amount ($)')
plt.title('Cash Status by ATM')
plt.xticks(x, atm_names)
plt.legend()
plt.grid(True, alpha=0.3)

# Add value labels
for i, (remaining, dispensed) in enumerate(zip(cash_remaining, cash_dispensed)):
    plt.text(i - width/2, remaining + ATM_CAPACITY * 0.01, f'${remaining:,}', 
             ha='center', va='bottom', rotation=0, fontsize=9)
    plt.text(i + width/2, dispensed + ATM_CAPACITY * 0.01, f'${dispensed:,}', 
             ha='center', va='bottom', rotation=0, fontsize=9)

plt.tight_layout()
plt.show()

# %%
# 5. Customers Served Over Time (Simulated Cumulative Data)
plt.figure(figsize=(12, 6))

# Since we don't have time-series data from the original simulation,
# we'll create a realistic representation based on the metrics
total_customers = metrics['customers_served']
simulation_time = SIM_DURATION

# Create time points and simulate cumulative customers served
time_points = np.linspace(0, simulation_time, 50)
# Simulate a realistic S-curve pattern for customer service
cumulative_customers = []
for t in time_points:
    # Use a logistic growth pattern that reaches the total at the end
    progress = t / simulation_time
    # S-curve formula that starts slow, accelerates, then slows down
    served = total_customers * (1 / (1 + np.exp(-8 * (progress - 0.5))))
    cumulative_customers.append(int(served))

plt.plot(time_points, cumulative_customers, 'b-', linewidth=3, marker='o', markersize=4)
plt.xlabel('Time (minutes)')
plt.ylabel('Cumulative Customers Served')
plt.title('Customers Served Over Time')
plt.grid(True, alpha=0.3)

# Add annotations
plt.text(0.7 * simulation_time, 0.3 * total_customers, 
         f'Total Served: {total_customers}\nSimulation Duration: {simulation_time} min', 
         bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))

plt.tight_layout()
plt.show()
