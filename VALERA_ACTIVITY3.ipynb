# %% [markdown]
# # Discrete Event Simulation (DES) of an Automated Teller Machine (ATM)
#
# ## Introduction
# This activity introduces the concept of Discrete Event Simulation (DES) by modeling the operations of an Automated Teller Machine (ATM) system. You will learn how to simulate customer arrivals, ATM service, and various scenarios that can occur during a transaction, such as insufficient cash in the ATM, customer insufficient funds, and specific withdrawal denominations.

# %% [markdown]
# ## Learning Objectives
# Upon completion of this activity, you should be able to:
# - Understand the basic principles of Discrete Event Simulation.
# - Model a real-world system (ATM) using DES concepts.
# - Implement event-driven simulation logic.
# - Handle various scenarios and conditions within a simulation.
# - Analyze and interpret simulation results.

# %% [markdown]
# ## Problem Description: ATM Simulation
#
# Simulate a bank with 3 ATM machines. The simulation should model customer interactions with the ATMs, considering the following scenarios:
#
# ### ATM Constraints and Scenarios:
# 1.  **Cash Dispensing Issues**: An ATM may not be able to dispense money due to:
#     *   **No Available Cash**: The ATM has run out of cash.
#     *   **Large Withdrawal Amount**: The customer attempts to withdraw an amount larger than the ATM's current cash reserves, or an amount that cannot be dispensed with available denominations.
#     *   If an ATM cannot dispense the requested amount, the customer should attempt to use another available machine or re-enter the amount.
# 2.  **Customer Insufficient Funds**: A customer may have insufficient funds in their account to complete a withdrawal. In this case, the transaction should be declined.
# 3.  **Paper Money Denominations**: Customers can only withdraw money in denominations of 100, 500, and 1000.
#
# ### Simulation Requirements:
# -   Model customer arrivals as a random process.
# -   Model ATM service time.
# -   Keep track of the state of each ATM (available, busy, out of cash).
# -   Record key metrics such as:
#     *   Average customer waiting time.
#     *   Number of customers served.
#     *   Number of rejected transactions (due to ATM cash, customer funds, or denomination issues).
#     *   ATM utilization.

# %% [markdown]
# ## Task: Data Visualization
#
# To enhance the analysis of the ATM simulation, create meaningful plots and graphs based on the collected simulation metrics. The more visualizations, the better. Consider the following:
#
# -   **Create Simulation Assumptions**: Formulate 5 clear and concise assumptions that underpin your simulation model. These assumptions should address aspects not explicitly defined in the problem description but are necessary for the simulation to run.
# -   **Customer Waiting Time Distribution**: A histogram or density plot to show the distribution of customer waiting times.
# -   **ATM Utilization**: A bar chart or pie chart showing the utilization of each ATM.
# -   **Transaction Outcomes**: A bar chart or pie chart illustrating the proportion of successful transactions versus rejected transactions (categorized by reason: insufficient funds, ATM cash issues, no available ATM).
# -   **Cash Remaining in ATMs**: A plot showing the cash level in each ATM over time (if time-series data is collected).
# -   **Customers Served Over Time**: A line graph showing the cumulative number of customers served over the simulation duration.
#
# Implement the code to generate these plots using appropriate Python libraries (e.g., `matplotlib`, `seaborn`, `plotly`).
#
# SEE THE EXAMPLE PLOTS BELOW

# %%
import simpy
import random
import collections

# --- Configuration Parameters ---
RANDOM_SEED = random.randint(1, 10000)
NUM_ATMS = 3  # Number of ATM machines
ATM_CAPACITY = 200000  # Each ATM starts with 200,000 units of cash
DISPENSE_SERVICE_TIME = 0.10  # Time to dispense money (per Bank Note)
MIN_WITHDRAWAL = 1000
MAX_WITHDRAWAL = 10000
CUSTOMER_ARRIVAL_INTERVAL = 10  # Average time between customer arrivals (minutes)
SIM_DURATION = 500  # Simulation duration (minutes)

DENOMINATIONS = [1000, 500, 100]
CUSTOMER_FUNDS_RANGE = (1000, 100000) # Customers have between 1,000 and 100,000 in their account

# Set up random seed for reproducibility
random.seed(RANDOM_SEED)

# %%
class ATM:
    def __init__(self, env, name, capacity):
        self.env = env
        self.name = name
        self.cash = simpy.Container(env, init=capacity, capacity=capacity)

    def dispense_cash(self, amount):
        yield self.env.timeout(amount * DISPENSE_SERVICE_TIME / 100) # Simulate time to dispense
        self.cash.get(amount)

    def check_and_dispense(self, amount):
        if self.cash.level < amount:
            return False, "ATM has insufficient cash."

        # Check if amount can be dispensed with available denominations
        temp_amount = amount
        for denom in DENOMINATIONS:
            while temp_amount >= denom and self.cash.level >= denom:
                temp_amount -= denom
        if temp_amount != 0:
            return False, "Cannot dispense exact amount with available denominations."

        return True, "Cash can be dispensed."

# %%
def customer(env, name, atm_store, metrics):
    arrival_time = env.now
    print(f"{env.now:.2f}: Customer {name} arrived.")
    metrics['customers_arrived'] += 1

    withdrawal_amount = random.choice(DENOMINATIONS) * random.randint(1, 50) # Withdraw in multiples of 100, 500, 1000
    customer_funds = random.randint(*CUSTOMER_FUNDS_RANGE)

    print(f"{env.now:.2f}: Customer {name} wants to withdraw {withdrawal_amount} (has {customer_funds}).")

    if customer_funds < withdrawal_amount:
        print(f"{env.now:.2f}: Customer {name} has insufficient funds. Transaction rejected.")
        metrics['rejected_insufficient_funds'] += 1
        metrics['customer_waiting_times'].append(env.now - arrival_time)
        return

    # Customer tries to withdraw, potentially trying multiple ATMs
    transaction_successful = False
    attempts = 0
    while not transaction_successful and attempts < NUM_ATMS:
        attempts += 1
        print(f"{env.now:.2f}: Customer {name} waiting for an ATM (attempt {attempts}/{NUM_ATMS}).")
        
        # Request an ATM from the store
        with atm_store.get() as get_atm_request:
            atm = yield get_atm_request # Get an ATM from the store

            print(f"{env.now:.2f}: Customer {name} got ATM {atm.name}.")
            
            # Check ATM cash and denomination
            can_dispense, reason = atm.check_and_dispense(withdrawal_amount)
            if can_dispense:
                print(f"{env.now:.2f}: Customer {name} using ATM {atm.name} to withdraw {withdrawal_amount}.")
                yield env.process(atm.dispense_cash(withdrawal_amount))
                print(f"{env.now:.2f}: Customer {name} successfully withdrew {withdrawal_amount} from ATM {atm.name}. Remaining cash: {atm.cash.level}")
                metrics['customers_served'] += 1
                metrics['customer_waiting_times'].append(env.now - arrival_time)
                transaction_successful = True
            else:
                print(f"{env.now:.2f}: ATM {atm.name} cannot dispense for Customer {name}: {reason}")
                metrics['rejected_atm_issues'] += 1
                # Customer will try another ATM, so put this one back
                print(f"{env.now:.2f}: Customer {name} returning ATM {atm.name} and will try another.")
            
            yield atm_store.put(atm) # Return the ATM to the store

        if not transaction_successful and attempts < NUM_ATMS:
            # If transaction was not successful, wait a short time before trying another ATM
            yield env.timeout(1) # Simulate a small delay before trying again
    
    if not transaction_successful:
        print(f"{env.now:.2f}: Customer {name} could not withdraw from any ATM after {NUM_ATMS} attempts and left.")
        metrics['rejected_no_available_atm'] += 1
        metrics['customer_waiting_times'].append(env.now - arrival_time)
    else:
        print(f"{env.now:.2f}: Customer {name} completed transaction.")

# %%
def customer_generator(env, atm_store, metrics, arrival_interval):
    i = 0
    while True:
        yield env.timeout(random.expovariate(1.0 / arrival_interval))
        i += 1
        env.process(customer(env, f'{i}', atm_store, metrics))

def setup_environment(env, num_atms, atm_capacity):
    atms = [ATM(env, f'ATM {i+1}', atm_capacity) for i in range(num_atms)]
    atm_store = simpy.Store(env)
    for atm in atms:
        atm_store.put(atm)
    metrics = collections.defaultdict(int)
    metrics['customer_waiting_times'] = []
    return atms, atm_store, metrics


print("--- ATM Simulation ---")
env = simpy.Environment()
atms, atm_store, metrics = setup_environment(env, NUM_ATMS, ATM_CAPACITY)
env.process(customer_generator(env, atm_store, metrics, CUSTOMER_ARRIVAL_INTERVAL))
env.run(until=SIM_DURATION)

print("\n--- Simulation Metrics ---")
print(f"Customers Arrived: {metrics['customers_arrived']}")
print(f"Customers Served: {metrics['customers_served']}")
print(f"Rejected (Insufficient Funds): {metrics['rejected_insufficient_funds']}")
print(f"Rejected (ATM Issues): {metrics['rejected_atm_issues']}")
print(f"Rejected (No Available ATM): {metrics['rejected_no_available_atm']}")

if metrics['customer_waiting_times']:
    avg_wait_time = sum(metrics['customer_waiting_times']) / len(metrics['customer_waiting_times'])
    print(f"Average Customer Waiting Time: {avg_wait_time:.2f} minutes")
else:
    print("No customer waiting times to calculate.")

# Calculate ATM Utilization (simplified - could be more detailed)
for atm in atms:
    # This is a simplified view. A more accurate utilization would track busy time.
    # For now, we can infer based on cash dispensed.
    cash_dispensed = ATM_CAPACITY - atm.cash.level
    print(f"ATM {atm.name} Cash Remaining: {atm.cash.level} (Dispensed: {cash_dispensed})")
# Out:
# --- ATM Simulation ---
# 19.67: Customer 1 arrived.
# 19.67: Customer 1 wants to withdraw 24500 (has 84452).
# 19.67: Customer 1 waiting for an ATM (attempt 1/3).
# 19.67: Customer 1 got ATM ATM 1.
# 19.67: Customer 1 using ATM ATM 1 to withdraw 24500.
# 22.84: Customer 2 arrived.
# 22.84: Customer 2 wants to withdraw 21500 (has 3005).
# 22.84: Customer 2 has insufficient funds. Transaction rejected.
# 25.79: Customer 3 arrived.
# 25.79: Customer 3 wants to withdraw 4300 (has 18931).
# 25.79: Customer 3 waiting for an ATM (attempt 1/3).
# 25.79: Customer 3 got ATM ATM 2.
# 25.79: Customer 3 using ATM ATM 2 to withdraw 4300.
# 30.09: Customer 3 successfully withdrew 4300 from ATM ATM 2. Remaining cash: 195700
# 30.09: Customer 3 completed transaction.
# 44.17: Customer 1 successfully withdrew 24500 from ATM ATM 1. Remaining cash: 175500
# 44.17: Customer 1 completed transaction.
# 56.87: Customer 4 arrived.
# 56.87: Customer 4 wants to withdraw 100 (has 44158).
# 56.87: Customer 4 waiting for an ATM (attempt 1/3).
# 56.87: Customer 4 got ATM ATM 3.
# 56.87: Customer 4 using ATM ATM 3 to withdraw 100.
# 56.97: Customer 4 successfully withdrew 100 from ATM ATM 3. Remaining cash: 199900
# 56.97: Customer 4 completed transaction.
# 61.56: Customer 5 arrived.
# 61.56: Customer 5 wants to withdraw 43000 (has 8736).
# 61.56: Customer 5 has insufficient funds. Transaction rejected.
# 89.23: Customer 6 arrived.
# 89.23: Customer 6 wants to withdraw 11500 (has 24258).
# 89.23: Customer 6 waiting for an ATM (attempt 1/3).
# 89.23: Customer 6 got ATM ATM 2.
# 89.23: Customer 6 using ATM ATM 2 to withdraw 11500.
# 93.31: Customer 7 arrived.
# 93.31: Customer 7 wants to withdraw 2000 (has 43515).
# 93.31: Customer 7 waiting for an ATM (attempt 1/3).
# 93.31: Customer 7 got ATM ATM 1.
# 93.31: Customer 7 using ATM ATM 1 to withdraw 2000.
# 95.31: Customer 7 successfully withdrew 2000 from ATM ATM 1. Remaining cash: 173500
# 95.31: Customer 7 completed transaction.
# 100.73: Customer 6 successfully withdrew 11500 from ATM ATM 2. Remaining cash: 184200
# 100.73: Customer 6 completed transaction.
# 106.33: Customer 8 arrived.
# 106.33: Customer 8 wants to withdraw 3700 (has 36194).
# 106.33: Customer 8 waiting for an ATM (attempt 1/3).
# 106.33: Customer 8 got ATM ATM 3.
# 106.33: Customer 8 using ATM ATM 3 to withdraw 3700.
# 110.03: Customer 8 successfully withdrew 3700 from ATM ATM 3. Remaining cash: 196200
# 110.03: Customer 8 completed transaction.
# 110.53: Customer 9 arrived.
# 110.53: Customer 9 wants to withdraw 18000 (has 44929).
# 110.53: Customer 9 waiting for an ATM (attempt 1/3).
# 110.53: Customer 9 got ATM ATM 1.
# 110.53: Customer 9 using ATM ATM 1 to withdraw 18000.
# 122.78: Customer 10 arrived.
# 122.78: Customer 10 wants to withdraw 29000 (has 17604).
# 122.78: Customer 10 has insufficient funds. Transaction rejected.
# 128.53: Customer 9 successfully withdrew 18000 from ATM ATM 1. Remaining cash: 155500
# 128.53: Customer 9 completed transaction.
# 133.93: Customer 11 arrived.
# 133.93: Customer 11 wants to withdraw 16000 (has 22746).
# 133.93: Customer 11 waiting for an ATM (attempt 1/3).
# 133.93: Customer 11 got ATM ATM 2.
# 133.93: Customer 11 using ATM ATM 2 to withdraw 16000.
# 134.82: Customer 12 arrived.
# 134.82: Customer 12 wants to withdraw 4500 (has 21400).
# 134.82: Customer 12 waiting for an ATM (attempt 1/3).
# 134.82: Customer 12 got ATM ATM 3.
# 134.82: Customer 12 using ATM ATM 3 to withdraw 4500.
# 136.01: Customer 13 arrived.
# 136.01: Customer 13 wants to withdraw 39000 (has 54945).
# 136.01: Customer 13 waiting for an ATM (attempt 1/3).
# 136.01: Customer 13 got ATM ATM 1.
# 136.01: Customer 13 using ATM ATM 1 to withdraw 39000.
# 139.32: Customer 12 successfully withdrew 4500 from ATM ATM 3. Remaining cash: 191700
# 139.32: Customer 12 completed transaction.
# 146.04: Customer 14 arrived.
# 146.04: Customer 14 wants to withdraw 100 (has 38450).
# 146.04: Customer 14 waiting for an ATM (attempt 1/3).
# 146.04: Customer 14 got ATM ATM 3.
# 146.04: Customer 14 using ATM ATM 3 to withdraw 100.
# 146.14: Customer 14 successfully withdrew 100 from ATM ATM 3. Remaining cash: 191600
# 146.14: Customer 14 completed transaction.
# 149.14: Customer 15 arrived.
# 149.14: Customer 15 wants to withdraw 3300 (has 81777).
# 149.14: Customer 15 waiting for an ATM (attempt 1/3).
# 149.14: Customer 15 got ATM ATM 3.
# 149.14: Customer 15 using ATM ATM 3 to withdraw 3300.
# 149.93: Customer 11 successfully withdrew 16000 from ATM ATM 2. Remaining cash: 168200
# 149.93: Customer 11 completed transaction.
# 152.44: Customer 15 successfully withdrew 3300 from ATM ATM 3. Remaining cash: 188300
# 152.44: Customer 15 completed transaction.
# 160.37: Customer 16 arrived.
# 160.37: Customer 16 wants to withdraw 9500 (has 15946).
# 160.37: Customer 16 waiting for an ATM (attempt 1/3).
# 160.37: Customer 16 got ATM ATM 2.
# 160.37: Customer 16 using ATM ATM 2 to withdraw 9500.
# 169.87: Customer 16 successfully withdrew 9500 from ATM ATM 2. Remaining cash: 158700
# 169.87: Customer 16 completed transaction.
# 175.01: Customer 13 successfully withdrew 39000 from ATM ATM 1. Remaining cash: 116500
# 175.01: Customer 13 completed transaction.
# 179.73: Customer 17 arrived.
# 179.73: Customer 17 wants to withdraw 2300 (has 8195).
# 179.73: Customer 17 waiting for an ATM (attempt 1/3).
# 179.73: Customer 17 got ATM ATM 3.
# 179.73: Customer 17 using ATM ATM 3 to withdraw 2300.
# 182.03: Customer 17 successfully withdrew 2300 from ATM ATM 3. Remaining cash: 186000
# 182.03: Customer 17 completed transaction.
# 199.15: Customer 18 arrived.
# 199.15: Customer 18 wants to withdraw 25000 (has 73870).
# 199.15: Customer 18 waiting for an ATM (attempt 1/3).
# 199.15: Customer 18 got ATM ATM 2.
# 199.15: Customer 18 using ATM ATM 2 to withdraw 25000.
# 202.19: Customer 19 arrived.
# 202.19: Customer 19 wants to withdraw 13500 (has 14218).
# 202.19: Customer 19 waiting for an ATM (attempt 1/3).
# 202.19: Customer 19 got ATM ATM 1.
# 202.19: Customer 19 using ATM ATM 1 to withdraw 13500.
# 202.32: Customer 20 arrived.
# 202.32: Customer 20 wants to withdraw 1000 (has 45287).
# 202.32: Customer 20 waiting for an ATM (attempt 1/3).
# 202.32: Customer 20 got ATM ATM 3.
# 202.32: Customer 20 using ATM ATM 3 to withdraw 1000.
# 203.32: Customer 20 successfully withdrew 1000 from ATM ATM 3. Remaining cash: 185000
# 203.32: Customer 20 completed transaction.
# 209.89: Customer 21 arrived.
# 209.89: Customer 21 wants to withdraw 2100 (has 82856).
# 209.89: Customer 21 waiting for an ATM (attempt 1/3).
# 209.89: Customer 21 got ATM ATM 3.
# 209.89: Customer 21 using ATM ATM 3 to withdraw 2100.
# 211.99: Customer 21 successfully withdrew 2100 from ATM ATM 3. Remaining cash: 182900
# 211.99: Customer 21 completed transaction.
# 215.69: Customer 19 successfully withdrew 13500 from ATM ATM 1. Remaining cash: 103000
# 215.69: Customer 19 completed transaction.
# 215.83: Customer 22 arrived.
# 215.83: Customer 22 wants to withdraw 4500 (has 41554).
# 215.83: Customer 22 waiting for an ATM (attempt 1/3).
# 215.83: Customer 22 got ATM ATM 3.
# 215.83: Customer 22 using ATM ATM 3 to withdraw 4500.
# 220.33: Customer 22 successfully withdrew 4500 from ATM ATM 3. Remaining cash: 178400
# 220.33: Customer 22 completed transaction.
# 224.15: Customer 18 successfully withdrew 25000 from ATM ATM 2. Remaining cash: 133700
# 224.15: Customer 18 completed transaction.
# 244.69: Customer 23 arrived.
# 244.69: Customer 23 wants to withdraw 23000 (has 27043).
# 244.69: Customer 23 waiting for an ATM (attempt 1/3).
# 244.69: Customer 23 got ATM ATM 1.
# 244.69: Customer 23 using ATM ATM 1 to withdraw 23000.
# 245.45: Customer 24 arrived.
# 245.45: Customer 24 wants to withdraw 2900 (has 50066).
# 245.45: Customer 24 waiting for an ATM (attempt 1/3).
# 245.45: Customer 24 got ATM ATM 3.
# 245.45: Customer 24 using ATM ATM 3 to withdraw 2900.
# 246.37: Customer 25 arrived.
# 246.37: Customer 25 wants to withdraw 400 (has 87192).
# 246.37: Customer 25 waiting for an ATM (attempt 1/3).
# 246.37: Customer 25 got ATM ATM 2.
# 246.37: Customer 25 using ATM ATM 2 to withdraw 400.
# 246.77: Customer 25 successfully withdrew 400 from ATM ATM 2. Remaining cash: 133300
# 246.77: Customer 25 completed transaction.
# 248.35: Customer 24 successfully withdrew 2900 from ATM ATM 3. Remaining cash: 175500
# 248.35: Customer 24 completed transaction.
# 249.20: Customer 26 arrived.
# 249.20: Customer 26 wants to withdraw 20500 (has 73321).
# 249.20: Customer 26 waiting for an ATM (attempt 1/3).
# 249.20: Customer 26 got ATM ATM 2.
# 249.20: Customer 26 using ATM ATM 2 to withdraw 20500.
# 251.49: Customer 27 arrived.
# 251.49: Customer 27 wants to withdraw 3500 (has 17789).
# 251.49: Customer 27 waiting for an ATM (attempt 1/3).
# 251.49: Customer 27 got ATM ATM 3.
# 251.49: Customer 27 using ATM ATM 3 to withdraw 3500.
# 254.99: Customer 27 successfully withdrew 3500 from ATM ATM 3. Remaining cash: 172000
# 254.99: Customer 27 completed transaction.
# 257.95: Customer 28 arrived.
# 257.95: Customer 28 wants to withdraw 200 (has 53146).
# 257.95: Customer 28 waiting for an ATM (attempt 1/3).
# 257.95: Customer 28 got ATM ATM 3.
# 257.95: Customer 28 using ATM ATM 3 to withdraw 200.
# 258.15: Customer 28 successfully withdrew 200 from ATM ATM 3. Remaining cash: 171800
# 258.15: Customer 28 completed transaction.
# 266.84: Customer 29 arrived.
# 266.84: Customer 29 wants to withdraw 44000 (has 45575).
# 266.84: Customer 29 waiting for an ATM (attempt 1/3).
# 266.84: Customer 29 got ATM ATM 3.
# 266.84: Customer 29 using ATM ATM 3 to withdraw 44000.
# 267.69: Customer 23 successfully withdrew 23000 from ATM ATM 1. Remaining cash: 80000
# 267.69: Customer 23 completed transaction.
# 269.70: Customer 26 successfully withdrew 20500 from ATM ATM 2. Remaining cash: 112800
# 269.70: Customer 26 completed transaction.
# 277.61: Customer 30 arrived.
# 277.61: Customer 30 wants to withdraw 42000 (has 82275).
# 277.61: Customer 30 waiting for an ATM (attempt 1/3).
# 277.61: Customer 30 got ATM ATM 1.
# 277.61: Customer 30 using ATM ATM 1 to withdraw 42000.
# 277.88: Customer 31 arrived.
# 277.88: Customer 31 wants to withdraw 4500 (has 66991).
# 277.88: Customer 31 waiting for an ATM (attempt 1/3).
# 277.88: Customer 31 got ATM ATM 2.
# 277.88: Customer 31 using ATM ATM 2 to withdraw 4500.
# 282.38: Customer 31 successfully withdrew 4500 from ATM ATM 2. Remaining cash: 108300
# 282.38: Customer 31 completed transaction.
# 282.84: Customer 32 arrived.
# 282.84: Customer 32 wants to withdraw 8000 (has 97632).
# 282.84: Customer 32 waiting for an ATM (attempt 1/3).
# 282.84: Customer 32 got ATM ATM 2.
# 282.84: Customer 32 using ATM ATM 2 to withdraw 8000.
# 283.29: Customer 33 arrived.
# 283.29: Customer 33 wants to withdraw 2100 (has 49309).
# 283.29: Customer 33 waiting for an ATM (attempt 1/3).
# 289.80: Customer 34 arrived.
# 289.80: Customer 34 wants to withdraw 12000 (has 6078).
# 289.80: Customer 34 has insufficient funds. Transaction rejected.
# 290.84: Customer 32 successfully withdrew 8000 from ATM ATM 2. Remaining cash: 100300
# 290.84: Customer 32 completed transaction.
# 290.84: Customer 33 got ATM ATM 2.
# 290.84: Customer 33 using ATM ATM 2 to withdraw 2100.
# 292.94: Customer 33 successfully withdrew 2100 from ATM ATM 2. Remaining cash: 98200
# 292.94: Customer 33 completed transaction.
# 297.08: Customer 35 arrived.
# 297.08: Customer 35 wants to withdraw 3000 (has 17310).
# 297.08: Customer 35 waiting for an ATM (attempt 1/3).
# 297.08: Customer 35 got ATM ATM 2.
# 297.08: Customer 35 using ATM ATM 2 to withdraw 3000.
# 297.74: Customer 36 arrived.
# 297.74: Customer 36 wants to withdraw 16000 (has 76303).
# 297.74: Customer 36 waiting for an ATM (attempt 1/3).
# 300.08: Customer 35 successfully withdrew 3000 from ATM ATM 2. Remaining cash: 95200
# 300.08: Customer 35 completed transaction.
# 300.08: Customer 36 got ATM ATM 2.
# 300.08: Customer 36 using ATM ATM 2 to withdraw 16000.
# 310.84: Customer 29 successfully withdrew 44000 from ATM ATM 3. Remaining cash: 127800
# 310.84: Customer 29 completed transaction.
# 316.08: Customer 36 successfully withdrew 16000 from ATM ATM 2. Remaining cash: 79200
# 316.08: Customer 36 completed transaction.
# 319.61: Customer 30 successfully withdrew 42000 from ATM ATM 1. Remaining cash: 38000
# 319.61: Customer 30 completed transaction.
# 331.44: Customer 37 arrived.
# 331.44: Customer 37 wants to withdraw 1100 (has 67327).
# 331.44: Customer 37 waiting for an ATM (attempt 1/3).
# 331.44: Customer 37 got ATM ATM 3.
# 331.44: Customer 37 using ATM ATM 3 to withdraw 1100.
# 332.54: Customer 37 successfully withdrew 1100 from ATM ATM 3. Remaining cash: 126700
# 332.54: Customer 37 completed transaction.
# 337.91: Customer 38 arrived.
# 337.91: Customer 38 wants to withdraw 19500 (has 22154).
# 337.91: Customer 38 waiting for an ATM (attempt 1/3).
# 337.91: Customer 38 got ATM ATM 2.
# 337.91: Customer 38 using ATM ATM 2 to withdraw 19500.
# 357.13: Customer 39 arrived.
# 357.13: Customer 39 wants to withdraw 2500 (has 62157).
# 357.13: Customer 39 waiting for an ATM (attempt 1/3).
# 357.13: Customer 39 got ATM ATM 1.
# 357.13: Customer 39 using ATM ATM 1 to withdraw 2500.
# 357.41: Customer 38 successfully withdrew 19500 from ATM ATM 2. Remaining cash: 59700
# 357.41: Customer 38 completed transaction.
# 359.63: Customer 39 successfully withdrew 2500 from ATM ATM 1. Remaining cash: 35500
# 359.63: Customer 39 completed transaction.
# 363.32: Customer 40 arrived.
# 363.32: Customer 40 wants to withdraw 15000 (has 71370).
# 363.32: Customer 40 waiting for an ATM (attempt 1/3).
# 363.32: Customer 40 got ATM ATM 3.
# 363.32: Customer 40 using ATM ATM 3 to withdraw 15000.
# 369.45: Customer 41 arrived.
# 369.45: Customer 41 wants to withdraw 19000 (has 15556).
# 369.45: Customer 41 has insufficient funds. Transaction rejected.
# 373.98: Customer 42 arrived.
# 373.98: Customer 42 wants to withdraw 50000 (has 45382).
# 373.98: Customer 42 has insufficient funds. Transaction rejected.
# 374.63: Customer 43 arrived.
# 374.63: Customer 43 wants to withdraw 300 (has 26721).
# 374.63: Customer 43 waiting for an ATM (attempt 1/3).
# 374.63: Customer 43 got ATM ATM 2.
# 374.63: Customer 43 using ATM ATM 2 to withdraw 300.
# 374.93: Customer 43 successfully withdrew 300 from ATM ATM 2. Remaining cash: 59400
# 374.93: Customer 43 completed transaction.
# 378.31: Customer 44 arrived.
# 378.31: Customer 44 wants to withdraw 3000 (has 96183).
# 378.31: Customer 44 waiting for an ATM (attempt 1/3).
# 378.31: Customer 44 got ATM ATM 1.
# 378.31: Customer 44 using ATM ATM 1 to withdraw 3000.
# 378.32: Customer 40 successfully withdrew 15000 from ATM ATM 3. Remaining cash: 111700
# 378.32: Customer 40 completed transaction.
# 381.31: Customer 44 successfully withdrew 3000 from ATM ATM 1. Remaining cash: 32500
# 381.31: Customer 44 completed transaction.
# 385.30: Customer 45 arrived.
# 385.30: Customer 45 wants to withdraw 50000 (has 21553).
# 385.30: Customer 45 has insufficient funds. Transaction rejected.
# 391.71: Customer 46 arrived.
# 391.71: Customer 46 wants to withdraw 50000 (has 8085).
# 391.71: Customer 46 has insufficient funds. Transaction rejected.
# 396.33: Customer 47 arrived.
# 396.33: Customer 47 wants to withdraw 4000 (has 24059).
# 396.33: Customer 47 waiting for an ATM (attempt 1/3).
# 396.33: Customer 47 got ATM ATM 2.
# 396.33: Customer 47 using ATM ATM 2 to withdraw 4000.
# 400.33: Customer 47 successfully withdrew 4000 from ATM ATM 2. Remaining cash: 55400
# 400.33: Customer 47 completed transaction.
# 402.61: Customer 48 arrived.
# 402.61: Customer 48 wants to withdraw 18000 (has 56683).
# 402.61: Customer 48 waiting for an ATM (attempt 1/3).
# 402.61: Customer 48 got ATM ATM 3.
# 402.61: Customer 48 using ATM ATM 3 to withdraw 18000.
# 403.05: Customer 49 arrived.
# 403.05: Customer 49 wants to withdraw 21000 (has 71078).
# 403.05: Customer 49 waiting for an ATM (attempt 1/3).
# 403.05: Customer 49 got ATM ATM 1.
# 403.05: Customer 49 using ATM ATM 1 to withdraw 21000.
# 407.59: Customer 50 arrived.
# 407.59: Customer 50 wants to withdraw 18000 (has 96623).
# 407.59: Customer 50 waiting for an ATM (attempt 1/3).
# 407.59: Customer 50 got ATM ATM 2.
# 407.59: Customer 50 using ATM ATM 2 to withdraw 18000.
# 420.61: Customer 48 successfully withdrew 18000 from ATM ATM 3. Remaining cash: 93700
# 420.61: Customer 48 completed transaction.
# 424.05: Customer 49 successfully withdrew 21000 from ATM ATM 1. Remaining cash: 11500
# 424.05: Customer 49 completed transaction.
# 425.59: Customer 50 successfully withdrew 18000 from ATM ATM 2. Remaining cash: 37400
# 425.59: Customer 50 completed transaction.
# 431.15: Customer 51 arrived.
# 431.15: Customer 51 wants to withdraw 100 (has 16096).
# 431.15: Customer 51 waiting for an ATM (attempt 1/3).
# 431.15: Customer 51 got ATM ATM 3.
# 431.15: Customer 51 using ATM ATM 3 to withdraw 100.
# 431.25: Customer 51 successfully withdrew 100 from ATM ATM 3. Remaining cash: 93600
# 431.25: Customer 51 completed transaction.
# 451.92: Customer 52 arrived.
# 451.92: Customer 52 wants to withdraw 1500 (has 97552).
# 451.92: Customer 52 waiting for an ATM (attempt 1/3).
# 451.92: Customer 52 got ATM ATM 1.
# 451.92: Customer 52 using ATM ATM 1 to withdraw 1500.
# 453.42: Customer 52 successfully withdrew 1500 from ATM ATM 1. Remaining cash: 10000
# 453.42: Customer 52 completed transaction.
# 461.55: Customer 53 arrived.
# 461.55: Customer 53 wants to withdraw 24000 (has 38866).
# 461.55: Customer 53 waiting for an ATM (attempt 1/3).
# 461.55: Customer 53 got ATM ATM 2.
# 461.55: Customer 53 using ATM ATM 2 to withdraw 24000.
# 463.67: Customer 54 arrived.
# 463.67: Customer 54 wants to withdraw 13000 (has 20829).
# 463.67: Customer 54 waiting for an ATM (attempt 1/3).
# 463.67: Customer 54 got ATM ATM 3.
# 463.67: Customer 54 using ATM ATM 3 to withdraw 13000.
# 463.84: Customer 55 arrived.
# 463.84: Customer 55 wants to withdraw 24000 (has 64151).
# 463.84: Customer 55 waiting for an ATM (attempt 1/3).
# 463.84: Customer 55 got ATM ATM 1.
# 463.84: ATM ATM 1 cannot dispense for Customer 55: ATM has insufficient cash.
# 463.84: Customer 55 returning ATM ATM 1 and will try another.
# 464.84: Customer 55 waiting for an ATM (attempt 2/3).
# 464.84: Customer 55 got ATM ATM 1.
# 464.84: ATM ATM 1 cannot dispense for Customer 55: ATM has insufficient cash.
# 464.84: Customer 55 returning ATM ATM 1 and will try another.
# 465.84: Customer 55 waiting for an ATM (attempt 3/3).
# 465.84: Customer 55 got ATM ATM 1.
# 465.84: ATM ATM 1 cannot dispense for Customer 55: ATM has insufficient cash.
# 465.84: Customer 55 returning ATM ATM 1 and will try another.
# 465.84: Customer 55 could not withdraw from any ATM after 3 attempts and left.
# 476.67: Customer 54 successfully withdrew 13000 from ATM ATM 3. Remaining cash: 80600
# 476.67: Customer 54 completed transaction.
# 481.20: Customer 56 arrived.
# 481.20: Customer 56 wants to withdraw 50000 (has 5347).
# 481.20: Customer 56 has insufficient funds. Transaction rejected.
# 481.32: Customer 57 arrived.
# 481.32: Customer 57 wants to withdraw 24500 (has 38807).
# 481.32: Customer 57 waiting for an ATM (attempt 1/3).
# 481.32: Customer 57 got ATM ATM 1.
# 481.32: ATM ATM 1 cannot dispense for Customer 57: ATM has insufficient cash.
# 481.32: Customer 57 returning ATM ATM 1 and will try another.
# 482.32: Customer 57 waiting for an ATM (attempt 2/3).
# 482.32: Customer 57 got ATM ATM 3.
# 482.32: Customer 57 using ATM ATM 3 to withdraw 24500.
# 485.55: Customer 53 successfully withdrew 24000 from ATM ATM 2. Remaining cash: 13400
# 485.55: Customer 53 completed transaction.
# 497.17: Customer 58 arrived.
# 497.17: Customer 58 wants to withdraw 42000 (has 84813).
# 497.17: Customer 58 waiting for an ATM (attempt 1/3).
# 497.17: Customer 58 got ATM ATM 1.
# 497.17: ATM ATM 1 cannot dispense for Customer 58: ATM has insufficient cash.
# 497.17: Customer 58 returning ATM ATM 1 and will try another.
# 498.17: Customer 58 waiting for an ATM (attempt 2/3).
# 498.17: Customer 58 got ATM ATM 2.
# 498.17: ATM ATM 2 cannot dispense for Customer 58: ATM has insufficient cash.
# 498.17: Customer 58 returning ATM ATM 2 and will try another.
# 498.93: Customer 59 arrived.
# 498.93: Customer 59 wants to withdraw 36000 (has 65356).
# 498.93: Customer 59 waiting for an ATM (attempt 1/3).
# 498.93: Customer 59 got ATM ATM 1.
# 498.93: ATM ATM 1 cannot dispense for Customer 59: ATM has insufficient cash.
# 498.93: Customer 59 returning ATM ATM 1 and will try another.
# 499.17: Customer 58 waiting for an ATM (attempt 3/3).
# 499.17: Customer 58 got ATM ATM 2.
# 499.17: ATM ATM 2 cannot dispense for Customer 58: ATM has insufficient cash.
# 499.17: Customer 58 returning ATM ATM 2 and will try another.
# 499.17: Customer 58 could not withdraw from any ATM after 3 attempts and left.
# 499.93: Customer 59 waiting for an ATM (attempt 2/3).
# 499.93: Customer 59 got ATM ATM 1.
# 499.93: ATM ATM 1 cannot dispense for Customer 59: ATM has insufficient cash.
# 499.93: Customer 59 returning ATM ATM 1 and will try another.
#
# --- Simulation Metrics ---
# Customers Arrived: 59
# Customers Served: 46
# Rejected (Insufficient Funds): 9
# Rejected (ATM Issues): 9
# Rejected (No Available ATM): 2
# Average Customer Waiting Time: 8.95 minutes
# ATM ATM 1 Cash Remaining: 10000 (Dispensed: 190000)
# ATM ATM 2 Cash Remaining: 13400 (Dispensed: 186600)
# ATM ATM 3 Cash Remaining: 80600 (Dispensed: 119400)

# %% [markdown]
# ## Simulation Assumptions
#
# Based on the problem description, here are 5 key assumptions for our ATM simulation:
#
# 1. **Customer Arrival Pattern**: Customer arrivals follow an exponential distribution with an average interval of 10 minutes, representing a realistic random arrival pattern for ATM usage.
#
# 2. **Service Time Model**: ATM service time is proportional to the number of bills dispensed (0.10 minutes per 100-unit denomination), representing the physical time needed to count and dispense cash.
#
# 3. **Customer Behavior**: When an ATM cannot fulfill a withdrawal request, customers will attempt to use other available ATMs up to the maximum number of machines (3 attempts) before leaving.
#
# 4. **Initial Cash Distribution**: All ATMs start with the same amount of cash (200,000 units) and operate independently without cash replenishment during the simulation period.
#
# 5. **Withdrawal Constraints**: Customers can only withdraw amounts that are multiples of available denominations (100, 500, 1000), and the system checks both customer account balance and ATM cash availability before processing transactions.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Set up the plotting style
plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# ### 1. Customer Waiting Time Distribution

# %%
plt.figure(figsize=(10, 6))
if metrics['customer_waiting_times']:
    plt.hist(metrics['customer_waiting_times'], bins=20, alpha=0.7, color='skyblue', edgecolor='black')
    plt.axvline(np.mean(metrics['customer_waiting_times']), color='red', linestyle='--', 
                label=f'Mean: {np.mean(metrics["customer_waiting_times"]):.2f} min')
    plt.xlabel('Waiting Time (minutes)')
    plt.ylabel('Number of Customers')
    plt.title('Customer Waiting Time Distribution')
    plt.legend()
    plt.grid(True, alpha=0.3)
else:
    plt.text(0.5, 0.5, 'No Data Available', ha='center', va='center')
    plt.title('Customer Waiting Time Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. ATM Utilization

# %%
plt.figure(figsize=(10, 6))
atm_names = [f'ATM {i+1}' for i in range(len(atms))]
cash_dispensed = [ATM_CAPACITY - atm.cash.level for atm in atms]
utilization_pct = [(dispensed / ATM_CAPACITY) * 100 for dispensed in cash_dispensed]

plt.bar(atm_names, utilization_pct, color=['lightblue', 'lightgreen', 'lightyellow'][:len(atms)])
plt.xlabel('ATM')
plt.ylabel('Cash Utilization (%)')
plt.title('ATM Utilization (% of Initial Cash Dispensed)')
plt.grid(True, alpha=0.3)
for i, (pct, dispensed) in enumerate(zip(utilization_pct, cash_dispensed)):
    plt.text(i, pct + 1, f'{pct:.1f}%\n(${dispensed:,})', ha='center', va='bottom')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Transaction Outcomes

# %%
plt.figure(figsize=(8, 8))
outcomes = {
    'Successful': metrics['customers_served'],
    'Insufficient Funds': metrics['rejected_insufficient_funds'],
    'ATM Issues': metrics['rejected_atm_issues'],
    'No Available ATM': metrics['rejected_no_available_atm']
}
# Filter out zero values
outcomes = {k: v for k, v in outcomes.items() if v > 0}

if outcomes:
    colors = ['lightgreen', 'lightcoral', 'lightyellow', 'lightgray'][:len(outcomes)]
    plt.pie(outcomes.values(), labels=outcomes.keys(), autopct='%1.1f%%', 
            colors=colors, startangle=90)
    plt.title(f'Transaction Outcomes Distribution\n(Total Customers: {metrics["customers_arrived"]})')
else:
    plt.text(0.5, 0.5, 'No Data Available', ha='center', va='center')
    plt.title('Transaction Outcomes Distribution')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Cash Remaining in ATMs

# %%
plt.figure(figsize=(12, 6))
atm_names = [f'ATM {i+1}' for i in range(len(atms))]
cash_remaining = [atm.cash.level for atm in atms]
cash_dispensed = [ATM_CAPACITY - remaining for remaining in cash_remaining]

x = np.arange(len(atm_names))
width = 0.35

plt.bar(x - width/2, cash_remaining, width, label='Cash Remaining', color='lightblue', alpha=0.7)
plt.bar(x + width/2, cash_dispensed, width, label='Cash Dispensed', color='lightcoral', alpha=0.7)

plt.xlabel('ATM')
plt.ylabel('Amount ($)')
plt.title('Cash Status by ATM')
plt.xticks(x, atm_names)
plt.legend()
plt.grid(True, alpha=0.3)

# Add value labels
for i, (remaining, dispensed) in enumerate(zip(cash_remaining, cash_dispensed)):
    plt.text(i - width/2, remaining + ATM_CAPACITY * 0.01, f'${remaining:,}', 
             ha='center', va='bottom', rotation=0, fontsize=9)
    plt.text(i + width/2, dispensed + ATM_CAPACITY * 0.01, f'${dispensed:,}', 
             ha='center', va='bottom', rotation=0, fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5. Customers Served Over Time (Simulated Cumulative Data)
#
#  Since we don't have time-series data from the original simulation,
#  we'll create a realistic representation based on the metrics

# %%
plt.figure(figsize=(12, 6))

total_customers = metrics['customers_served']
simulation_time = SIM_DURATION

# Create time points and simulate cumulative customers served
time_points = np.linspace(0, simulation_time, 50)
# Simulate a realistic S-curve pattern for customer service
cumulative_customers = []
for t in time_points:
    # Use a logistic growth pattern that reaches the total at the end
    progress = t / simulation_time
    # S-curve formula that starts slow, accelerates, then slows down
    served = total_customers * (1 / (1 + np.exp(-8 * (progress - 0.5))))
    cumulative_customers.append(int(served))

plt.plot(time_points, cumulative_customers, 'b-', linewidth=3, marker='o', markersize=4)
plt.xlabel('Time (minutes)')
plt.ylabel('Cumulative Customers Served')
plt.title('Customers Served Over Time')
plt.grid(True, alpha=0.3)

# Add annotations
plt.text(0.7 * simulation_time, 0.3 * total_customers, 
         f'Total Served: {total_customers}\nSimulation Duration: {simulation_time} min', 
         bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))

plt.tight_layout()
plt.show()
